# %% [markdown]
# # Purpose
# (Step 1.)
# Parse the original text files and convert them into CSVs for pandas manipulation later

# %%
import numpy as np
import os
import pandas as pd
from pathlib import Path
import pandas as pd
from tqdm.notebook import tqdm

# %%
ROOT_DIR = Path.cwd().parent
DATA_DIR = ROOT_DIR / "data" 
MANIFEST_DATA_DIR = DATA_DIR / "manifest/who_ddx"
RAW_DATA_DIR = DATA_DIR / "raw"
CSV_DATA_DIR = DATA_DIR / "to_csv"
TXT_DATA_DIR = RAW_DATA_DIR / "20210901"
MAIN_TXT_DATA_DIR = TXT_DATA_DIR / "who_ddx"

# %%
table_name = "MP"

# Get Manifest
fpath = MANIFEST_DATA_DIR / f"{table_name}.csv"
manifest_adr = pd.read_csv(fpath, index_col=0)
columns_adr = manifest_adr["column_name"].values
display(manifest_adr)
manifest_adr = manifest_adr.to_dict(orient="records")

# Get Counts
fpath = MANIFEST_DATA_DIR / "count.csv"
# count = pd.read_csv(fpath, index_col=0)
count = pd.read_csv(fpath)
n_rows = count.loc[count["Table"] == table_name, "No of rows"].squeeze()
display(count)

# # Parse text file
fpath = MAIN_TXT_DATA_DIR / f"{table_name}.txt"
results = [None for _ in range(n_rows)]
result = [None for _ in range(len(manifest_adr))]
with open(fpath) as file:
  for idx, line in tqdm(enumerate(file), total=n_rows):
      for icol, col in enumerate(manifest_adr):
        char_start = col["char_position_start"]
        char_end = col["char_position_end"]
        # Subtract one since raw table was 1-indexed
        result[icol] =  line[char_start -1: char_end].rstrip()
      results[idx] = tuple(result)
df = pd.DataFrame(results, columns=columns_adr)
df.head()
# Out:
#                                 column_name          dtype  number_of_chars  \
# 0                          Medicinalprod_Id  <class 'str'>               10
# 1                                     MedID  <class 'str'>               35
# 2                        Drug record number  <class 'str'>                6
# 3                         Sequence number 1  <class 'str'>                2
# 4                         Sequence number 2  <class 'str'>                3
# 5                         Sequence number 3  <class 'str'>               10
# 6                         Sequence number 4  <class 'str'>               10
# 7                                   Generic  <class 'str'>                1
# 8                                 Drug name  <class 'str'>             1500
# 9                            Name specifier  <class 'str'>               30
# 10           Marketing Authorization Number  <class 'str'>               30
# 11             Marketing Authorization Date  <class 'str'>                8
# 12  Marketing Authorization Withdrawal Date  <class 'str'>                8
# 13                                  Country  <class 'str'>               10
# 14                                  Company  <class 'str'>               10
# 15           Marketing Authorization Holder  <class 'str'>               10
# 16                           Reference code  <class 'str'>               10
# 17                           Source country  <class 'str'>               10
# 18                        Year of Reference  <class 'str'>                3
# 19                             Product type  <class 'str'>               10
# 20                            Product group  <class 'str'>               10
# 21                              Create date  <class 'str'>                8
# 22                             Date changed  <class 'str'>                8
#
#     char_position_start  char_position_end  \
# 0                     1                 10
# 1                    11                 45
# 2                    46                 51
# 3                    52                 53
# 4                    54                 56
# 5                    57                 66
# 6                    67                 76
# 7                    77                 77
# 8                    78               1577
# 9                  1578               1607
# 10                 1608               1637
# 11                 1638               1645
# 12                 1646               1653
# 13                 1654               1663
# 14                 1664               1673
# 15                 1674               1683
# 16                 1684               1693
# 17                 1694               1703
# 18                 1704               1706
# 19                 1707               1716
# 20                 1717               1726
# 21                 1727               1734
# 22                 1735               1742
#
#                                                 notes
# 0                          Medicinal Product idenfier
# 1                                          'Not used'
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                              Y or N
# 8                                                 NaN
# 9                                                 NaN
# 10                                         'Not used'
# 11                                         'Not used'
# 12                                         'Not used'
# 13  CCODE. Country code Marketing country. A 3-cha...
# 14                               ORG.Organization_Id.
# 15                               ORG.Organization_Id.
# 16                                SRCE.Reference code
# 17                               CCODE. Country code.
# 18                                                NaN
# 19                                   PRT.Prodtype_Id.
# 20                               PRG.Productgroup_Id.
# 21                                                NaN
# 22                                                NaN
#    Dictionary Format   Table  No of rows  Unnamed: 4
# 0         DDX     C3     ATC        1425         NaN
# 1         DDX     C3   CCODE         247         NaN
# 2         DDX     C3     ING      574603         NaN
# 3         DDX     C3      MP      293144         NaN
# 4         DDX     C3     ORG        2399         NaN
# 5         DDX     C3      PF         226         NaN
# 6         DDX     C3      PP      293144         NaN
# 7         DDX     C3     PRG           1         NaN
# 8         DDX     C3     PRT          10         NaN
# 9         DDX     C3    SRCE         473         NaN
# 10        DDX     C3     STR          78         NaN
# 11        DDX     C3     SUN       14884         NaN
# 12        DDX     C3     ThG      345137         NaN
# 13        DDX     C3    UNIT          68         NaN
# 14        DDX     C3  Unit-L          68         NaN
# 15        DDX     C3  Unit-X          68         NaN
#   0%|          | 0/293144 [00:00<?, ?it/s]
#   Medicinalprod_Id MedID Drug record number Sequence number 1  \
# 0                1                   000001                01
# 1           100002                   002562                01
# 2           100004                   002562                01
# 3           100005                   002562                01
# 4           100008                   002562                01
#
#   Sequence number 2 Sequence number 3 Sequence number 4 Generic     Drug name  \
# 0               001        0000000001        0000000001       Y    Methyldopa
# 1               004        0000000001        0000000001       N    Naprometin
# 2               006        0000000001        0000000001       N  Apo-naproxen
# 3               007        0000000001        0000000001       N         Naxen
# 4               010        0000000001        0000000001       N        Napren
#
#   Name specifier  ... Country Company Marketing Authorization Holder  \
# 0                 ...     N/A                                      0
# 1                 ...     UNS                                   7157
# 2                 ...     UNS                                   7157
# 3                 ...     UNS                                   7157
# 4                 ...     UNS                                   7157
#
#   Reference code Source country Year of Reference Product type Product group  \
# 0            001            N/A                            001             0
# 1            051            FIN                78          001             0
# 2            ZWE            ZWE                18          001             0
# 3            335            KOR                20          001             0
# 4            028            NOR                85          001             0
#
#   Create date Date changed
# 0    19851231     20170907
# 1    20041231     20071207
# 2    20041231     20180507
# 3    20041231     20201130
# 4    20041231     20071208
#
# [5 rows x 23 columns]

# %%
df[df["Drug record number"] == "13675"]
# Out:
# Empty DataFrame
# Columns: [Medicinalprod_Id, MedID, Drug record number, Sequence number 1, Sequence number 2, Sequence number 3, Sequence number 4, Generic, Drug name, Name specifier, Marketing Authorization Number, Marketing Authorization Date, Marketing Authorization Withdrawal Date, Country, Company, Marketing Authorization Holder, Reference code, Source country, Year of Reference, Product type, Product group, Create date, Date changed]
# Index: []
#
# [0 rows x 23 columns]

# %%
"13675" in df["Drug record number"].unique()
# Out:
# False

# %%
df[[a.startswith("Viagra") for a in df["Drug name"]]].groupby("Medicinalprod_Id").sum()
# for n, d in df[[a.startswith("Viagra") for a in df["Drug name"]]].groupby("Medicinalprod_Id"):
#    display(n, d)
# Out:
#                  MedID Drug record number Sequence number 1 Sequence number 2  \
# Medicinalprod_Id
# 1257069                            013675                02               002
# 1262124                            013675                02               002
# 1268339                            013675                02               002
# 1271479                            013675                02               002
# 1282231                            013675                02               002
# 1287329                            013675                02               002
# 1293034                            013675                02               002
# 1295477                            013675                02               002
# 1303116                            013675                02               002
# 1305477                            013675                02               002
# 1308971                            013675                02               002
# 1315316                            013675                02               002
# 1318998                            013675                02               002
# 1321280                            013675                02               002
# 1328401                            013675                02               002
# 1332062                            013675                02               002
# 1335551                            013675                02               002
# 1337536                            013675                02               002
# 1342522                            013675                02               002
# 1350774                            013675                02               002
# 1360725                            013675                02               002
# 1362798                            013675                02               002
# 1364782                            013675                02               002
# 1367178                            013675                02               002
# 1369904                            013675                02               002
# 1373819                            013675                02               002
# 1376191                            013675                02               002
# 1410196                            013675                02               002
# 1412697                            013675                02               002
# 1416688                            013675                02               002
# 1421960                            013675                02               002
# 1423254                            013675                02               002
# 1425366                            013675                02               002
# 1427239                            013675                02               002
# 1428999                            013675                02               002
# 1430281                            013675                02               002
# 1432736                            013675                02               002
# 1442122                            013675                02               002
# 1448297                            013675                02               002
# 1450944                            013675                02               002
# 1453154                            013675                02               002
# 1465721                            013675                02               002
# 1472464                            013675                02               002
# 1482282                            013675                02               002
# 1519899                            013675                02               002
# 1590218                            013675                02               002
# 2244277                            013675                02               234
# 2548924                            013675                02               002
# 2717044                            013675                02               332
# 4136975                            013675                02               668
# 4169340                            013675                02               002
# 4191303                            013675                02               679
# 4191304                            013675                02               679
# 57543                              013675                02               002
#
#                  Sequence number 3 Sequence number 4 Generic       Drug name  \
# Medicinalprod_Id
# 1257069                 0000000001        0000000001       N          Viagra
# 1262124                 0000000001        0000000001       N          Viagra
# 1268339                 0000000001        0000000001       N          Viagra
# 1271479                 0000000001        0000000001       N          Viagra
# 1282231                 0000000001        0000000001       N          Viagra
# 1287329                 0000000001        0000000001       N          Viagra
# 1293034                 0000000001        0000000001       N          Viagra
# 1295477                 0000000001        0000000001       N          Viagra
# 1303116                 0000000001        0000000001       N          Viagra
# 1305477                 0000000001        0000000001       N          Viagra
# 1308971                 0000000001        0000000001       N          Viagra
# 1315316                 0000000001        0000000001       N          Viagra
# 1318998                 0000000001        0000000001       N          Viagra
# 1321280                 0000000001        0000000001       N          Viagra
# 1328401                 0000000001        0000000001       N          Viagra
# 1332062                 0000000001        0000000001       N          Viagra
# 1335551                 0000000001        0000000001       N          Viagra
# 1337536                 0000000001        0000000001       N          Viagra
# 1342522                 0000000001        0000000001       N          Viagra
# 1350774                 0000000001        0000000001       N          Viagra
# 1360725                 0000000001        0000000001       N          Viagra
# 1362798                 0000000001        0000000001       N          Viagra
# 1364782                 0000000001        0000000001       N          Viagra
# 1367178                 0000000001        0000000001       N          Viagra
# 1369904                 0000000001        0000000001       N          Viagra
# 1373819                 0000000001        0000000001       N          Viagra
# 1376191                 0000000001        0000000001       N          Viagra
# 1410196                 0000000001        0000000001       N          Viagra
# 1412697                 0000000001        0000000001       N          Viagra
# 1416688                 0000000001        0000000001       N          Viagra
# 1421960                 0000000001        0000000001       N          Viagra
# 1423254                 0000000001        0000000001       N          Viagra
# 1425366                 0000000001        0000000001       N          Viagra
# 1427239                 0000000001        0000000001       N          Viagra
# 1428999                 0000000001        0000000001       N          Viagra
# 1430281                 0000000001        0000000001       N          Viagra
# 1432736                 0000000001        0000000001       N          Viagra
# 1442122                 0000000001        0000000001       N          Viagra
# 1448297                 0000000001        0000000001       N          Viagra
# 1450944                 0000000001        0000000001       N          Viagra
# 1453154                 0000000001        0000000001       N          Viagra
# 1465721                 0000000001        0000000001       N          Viagra
# 1472464                 0000000001        0000000001       N          Viagra
# 1482282                 0000000001        0000000001       N          Viagra
# 1519899                 0000000001        0000000001       N          Viagra
# 1590218                 0000000001        0000000001       N          Viagra
# 2244277                 0000000001        0000000001       N      Viagra Jet
# 2548924                 0000000001        0000000001       N          Viagra
# 2717044                 0000000001        0000000001       N        Viagra L
# 4136975                 0000000001        0000000001       N      Viagra odt
# 4169340                 0000000001        0000000001       N          Viagra
# 4191303                 0000000001        0000000001       N  Viagra connect
# 4191304                 0000000001        0000000001       N  Viagra connect
# 57543                   0000000001        0000000001       N          Viagra
#
#                  Name specifier Marketing Authorization Number  ... Country  \
# Medicinalprod_Id                                                ...
# 1257069                                                         ...     SWE
# 1262124                                                         ...     CHE
# 1268339                                                         ...     DEU
# 1271479                                                         ...     FIN
# 1282231                                                         ...     JPN
# 1287329                                                         ...     GBR
# 1293034                                                         ...     EST
# 1295477                                                         ...     CZE
# 1303116                                                         ...     LVA
# 1305477                                                         ...     HUN
# 1308971                                                         ...     POL
# 1315316                                                         ...     MEX
# 1318998                                                         ...     AUT
# 1321280                                                         ...     CAN
# 1328401                                                         ...     USA
# 1332062                                                         ...     FRA
# 1335551                                                         ...     ITA
# 1337536                                                         ...     NLD
# 1342522                                                         ...     BRA
# 1350774                                                         ...     ARG
# 1360725                                                         ...     BEL
# 1362798                                                         ...     AUS
# 1364782                                                         ...     PRT
# 1367178                                                         ...     TUR
# 1369904                                                         ...     GRC
# 1373819                                                         ...     IRL
# 1376191                                                         ...     PER
# 1410196                                                         ...     MYS
# 1412697                                                         ...     SGP
# 1416688                                                         ...     SVK
# 1421960                                                         ...     SVN
# 1423254                                                         ...     ISR
# 1425366                                                         ...     CHL
# 1427239                                                         ...     ARE
# 1428999                                                         ...     MAR
# 1430281                                                         ...     NOR
# 1432736                                                         ...     ZAF
# 1442122                                                         ...     PHL
# 1448297                                                         ...     SAU
# 1450944                                                         ...     EGY
# 1453154                                                         ...     VEN
# 1465721                                                         ...     BGR
# 1472464                                                         ...     UKR
# 1482282                                                         ...     THA
# 1519899                                                         ...     ESP
# 1590218                                                         ...     HRV
# 2244277                                                         ...     UNS
# 2548924                                                         ...     TUN
# 2717044                                                         ...     UNS
# 4136975                                                         ...     UNS
# 4169340                                                         ...     ZWE
# 4191303                                                         ...     GBR
# 4191304                                                         ...     UNS
# 57543                                                           ...     UNS
#
#                  Company Marketing Authorization Holder Reference code  \
# Medicinalprod_Id
# 1257069                                            7157            022
# 1262124                                            7157            CHE
# 1268339                                            7157            015
# 1271479                                            7157            237
# 1282231                                            7157            237
# 1287329                                            7157            237
# 1293034                                            7157            237
# 1295477                                            7157            237
# 1303116                                            7157            336
# 1305477                                            7157            237
# 1308971                                            7157            336
# 1315316                                            7157            237
# 1318998                                            7157            237
# 1321280                                            7157            237
# 1328401                                            7157            237
# 1332062                                            7157            237
# 1335551                                            7157            237
# 1337536                                            7157            237
# 1342522                                            7157            237
# 1350774                                            7157            237
# 1360725                                            7157            237
# 1362798                                            7157            237
# 1364782                                            7157            237
# 1367178                                            7157            237
# 1369904                                            7157            237
# 1373819                                            7157            237
# 1376191                                            7157            237
# 1410196                                            7157            237
# 1412697                                            7157            237
# 1416688                                            7157            237
# 1421960                                            7157            237
# 1423254                                            7157            237
# 1425366                                            7157            237
# 1427239                                            7157            237
# 1428999                                            7157            237
# 1430281                                            7157            237
# 1432736                                            7157            237
# 1442122                                            7157            237
# 1448297                                            7157            336
# 1450944                                            7157            237
# 1453154                                            7157            237
# 1465721                                            7157            237
# 1472464                                            7157            237
# 1482282                                            7157            237
# 1519899                                            7157            237
# 1590218                                            7157            251
# 2244277                                            7157            237
# 2548924                                            7157            254
# 2717044                                            7157            335
# 4136975                                            7157            237
# 4169340                                            7157            ZWE
# 4191303                                            7157            237
# 4191304                                            7157            336
# 57543                                              7157            PRY
#
#                  Source country Year of Reference Product type Product group  \
# Medicinalprod_Id
# 1257069                     SWE                98          001             0
# 1262124                     CHE                03          001             0
# 1268339                     DEU                03          001             0
# 1271479                     N/A                05          001             0
# 1282231                     N/A                05          001             0
# 1287329                     N/A                05          001             0
# 1293034                     N/A                05          001             0
# 1295477                     N/A                05          001             0
# 1303116                     N/A                19          001             0
# 1305477                     N/A                05          001             0
# 1308971                     N/A                19          001             0
# 1315316                     N/A                05          001             0
# 1318998                     N/A                17          001             0
# 1321280                     N/A                05          001             0
# 1328401                     N/A                05          001             0
# 1332062                     N/A                05          001             0
# 1335551                     N/A                18          001             0
# 1337536                     N/A                05          001             0
# 1342522                     N/A                05          001             0
# 1350774                     N/A                16          001             0
# 1360725                     N/A                05          001             0
# 1362798                     N/A                05          001             0
# 1364782                     N/A                05          001             0
# 1367178                     N/A                05          001             0
# 1369904                     N/A                05          001             0
# 1373819                     N/A                05          001             0
# 1376191                     N/A                05          001             0
# 1410196                     N/A                05          001             0
# 1412697                     N/A                05          001             0
# 1416688                     N/A                05          001             0
# 1421960                     N/A                05          001             0
# 1423254                     N/A                05          001             0
# 1425366                     N/A                05          001             0
# 1427239                     N/A                05          001             0
# 1428999                     N/A                05          001             0
# 1430281                     N/A                17          001             0
# 1432736                     N/A                05          001             0
# 1442122                     N/A                05          001             0
# 1448297                     N/A                20          001             0
# 1450944                     N/A                05          001             0
# 1453154                     N/A                05          001             0
# 1465721                     N/A                05          001             0
# 1472464                     N/A                05          001             0
# 1482282                     N/A                05          001             0
# 1519899                     N/A                16          001             0
# 1590218                     HRV                09          001             0
# 2244277                     N/A                11          001             0
# 2548924                     N/A                12          001             0
# 2717044                     KOR                20          001             0
# 4136975                     N/A                18          001             0
# 4169340                     ZWE                18          001             0
# 4191303                     N/A                18          001             0
# 4191304                     N/A                21          001             0
# 57543                       PRY                20          001             0
#
#                  Create date Date changed
# Medicinalprod_Id
# 1257069             20080125     20210309
# 1262124             20080125     20080125
# 1268339             20080125     20210108
# 1271479             20080125     20080125
# 1282231             20080125     20080125
# 1287329             20080125     20080125
# 1293034             20080125     20201130
# 1295477             20080125     20080125
# 1303116             20080125     20190516
# 1305477             20080125     20080125
# 1308971             20080125     20191206
# 1315316             20080125     20080125
# 1318998             20080125     20170824
# 1321280             20080125     20080125
# 1328401             20080125     20080125
# 1332062             20080125     20080125
# 1335551             20080125     20181003
# 1337536             20080125     20080125
# 1342522             20080125     20080125
# 1350774             20080125     20160215
# 1360725             20080125     20080125
# 1362798             20080125     20080125
# 1364782             20080125     20080125
# 1367178             20080125     20080125
# 1369904             20080125     20080125
# 1373819             20080125     20080125
# 1376191             20080125     20080125
# 1410196             20080125     20080125
# 1412697             20080125     20080125
# 1416688             20080125     20080125
# 1421960             20080125     20080125
# 1423254             20080125     20080125
# 1425366             20080125     20080125
# 1427239             20080125     20080125
# 1428999             20080125     20080125
# 1430281             20080125     20170607
# 1432736             20080125     20080125
# 1442122             20080125     20080125
# 1448297             20080125     20210201
# 1450944             20080125     20130902
# 1453154             20080125     20080125
# 1465721             20080125     20080125
# 1472464             20080125     20080125
# 1482282             20080125     20080125
# 1519899             20080125     20160422
# 1590218             20090223     20090223
# 2244277             20110501     20110501
# 2548924             20121101     20121101
# 2717044             20130603     20201214
# 4136975             20180322     20180322
# 4169340             20180522     20180522
# 4191303             20180618     20180618
# 4191304             20180618     20210304
# 57543               20030627     20210311
#
# [54 rows x 22 columns]

# %%
#df[[a.startswith("Viagra") for a in df["Drug name"]]].groupby(["Drug record number", "Drug name"]).count()
df.index = df["Drug record number"]
df.loc["013675"]
# df.groupby(["Drug record number"]).first().loc["013675"].to_frame().T
# Out:
#                    Medicinalprod_Id MedID Drug record number  \
# Drug record number
# 013675                      1093411                   013675
# 013675                      1179238                   013675
# 013675                      1257069                   013675
# 013675                      1262124                   013675
# 013675                      1268339                   013675
# ...                             ...   ...                ...
# 013675                        57543                   013675
# 013675                       640018                   013675
# 013675                       642108                   013675
# 013675                       755643                   013675
# 013675                       829340                   013675
#
#                    Sequence number 1 Sequence number 2 Sequence number 3  \
# Drug record number
# 013675                            02               127        0000000001
# 013675                            02               128        0000000001
# 013675                            02               002        0000000001
# 013675                            02               002        0000000001
# 013675                            02               002        0000000001
# ...                              ...               ...               ...
# 013675                            02               002        0000000001
# 013675                            02               066        0000000001
# 013675                            02               067        0000000001
# 013675                            02               093        0000000001
# 013675                            02               103        0000000001
#
#                    Sequence number 4 Generic Drug name Name specifier  ...  \
# Drug record number                                                     ...
# 013675                    0000000001       N   Revatio                 ...
# 013675                    0000000001       N    Zoltan                 ...
# 013675                    0000000001       N    Viagra                 ...
# 013675                    0000000001       N    Viagra                 ...
# 013675                    0000000001       N    Viagra                 ...
# ...                              ...     ...       ...            ...  ...
# 013675                    0000000001       N    Viagra                 ...
# 013675                    0000000001       N   Zenegra                 ...
# 013675                    0000000001       N  Ultimate                 ...
# 013675                    0000000001       N     Alfin                 ...
# 013675                    0000000001       N     Eleve                 ...
#
#                    Country Company Marketing Authorization Holder  \
# Drug record number
# 013675                 UNS                                   7157
# 013675                 UNS                                   7157
# 013675                 SWE                                   7157
# 013675                 CHE                                   7157
# 013675                 DEU                                   7157
# ...                    ...     ...                            ...
# 013675                 UNS                                   7157
# 013675                 UNS                                   7157
# 013675                 UNS                                   7157
# 013675                 UNS                                   7157
# 013675                 UNS                                   7157
#
#                    Reference code Source country Year of Reference  \
# Drug record number
# 013675                        336            N/A                21
# 013675                        237            N/A                07
# 013675                        022            SWE                98
# 013675                        CHE            CHE                03
# 013675                        015            DEU                03
# ...                           ...            ...               ...
# 013675                        PRY            PRY                20
# 013675                        237            N/A                05
# 013675                        237            N/A                05
# 013675                        237            N/A                05
# 013675                        237            N/A                05
#
#                    Product type Product group Create date Date changed
# Drug record number
# 013675                      001             0    20060418     20210331
# 013675                      001             0    20070716     20120702
# 013675                      001             0    20080125     20210309
# 013675                      001             0    20080125     20080125
# 013675                      001             0    20080125     20210108
# ...                         ...           ...         ...          ...
# 013675                      001             0    20030627     20210311
# 013675                      001             0    20051228     20051228
# 013675                      001             0    20051228     20051228
# 013675                      001             0    20051229     20051229
# 013675                      001             0    20051229     20120601
#
# [337 rows x 23 columns]

# %%
help(df.groupby(["Drug record number"]).first)
# Out:
# Help on method first in module pandas.core.groupby.groupby:
#
# first(numeric_only: 'bool' = False, min_count: 'int' = -1) method of pandas.core.groupby.generic.DataFrameGroupBy instance
#     Compute first of group values.
#
#     Parameters
#     ----------
#     numeric_only : bool, default False
#         Include only float, int, boolean columns. If None, will attempt to use
#         everything, then use only numeric data.
#     min_count : int, default -1
#         The required number of valid values to perform the operation. If fewer
#         than ``min_count`` non-NA values are present the result will be NA.
#
#     Returns
#     -------
#     Series or DataFrame
#         Computed first of values within each group.

# %%
df.columns
# Out:
# Index(['Medicinalprod_Id', 'MedID', 'Drug record number', 'Sequence number 1',
#        'Sequence number 2', 'Sequence number 3', 'Sequence number 4',
#        'Generic', 'Drug name', 'Name specifier',
#        'Marketing Authorization Number', 'Marketing Authorization Date',
#        'Marketing Authorization Withdrawal Date', 'Country', 'Company',
#        'Marketing Authorization Holder', 'Reference code', 'Source country',
#        'Year of Reference', 'Product type', 'Product group', 'Create date',
#        'Date changed'],
#       dtype='object')

# %%
# df.to_csv(CSV_DATA_DIR / f"{table_name}.csv")
# print(f"Saved {table_name}.csv!")
# del df

# %%
# df.to_csv(CSV_DATA_DIR / f"{table_name}.csv")

# %%
table_name = "DEMO"

# Get Manifest
fpath = MANIFEST_DATA_DIR / f"{table_name}.csv"
manifest_adr = pd.read_csv(fpath, index_col=0)
columns_adr = manifest_adr["column_name"].values
display(manifest_adr)
manifest_adr = manifest_adr.to_dict(orient="records")

# Get Counts
fpath = MANIFEST_DATA_DIR / "count.csv"
count = pd.read_csv(fpath, index_col=0)
n_rows = count.loc[count["Table"] == table_name, "No of rows"].squeeze()
display(count)

# Parse text file
fpath = MAIN_TXT_DATA_DIR / f"{table_name}.txt"
results = [None for _ in range(n_rows)]
result = [None for _ in range(len(manifest_adr))]
with open(fpath) as file:
  for idx, line in tqdm(enumerate(file), total=n_rows):
      for icol, col in enumerate(manifest_adr):
        char_start = col["char_position_start"]
        char_end = col["char_position_end"]
        result[icol] =  line[char_start: char_end].rstrip()
      results[idx] = tuple(result)
df = pd.DataFrame(results, columns=columns_adr)
df.head()
# Out:
#          column_name          dtype  number_of_chars  char_position_start  \
# 0        UMCReportId  <class 'int'>               11                    0
# 1           AgeGroup  <class 'str'>                1                   11
# 2             Gender  <class 'str'>                1                   12
# 3       DateDatabase  <class 'str'>                8                   13
# 4               Type  <class 'str'>                1                   21
# 5             Region  <class 'str'>                1                   22
# 6  FirstDateDatabase  <class 'str'>                8                   23
#
#    char_position_end                                              notes
# 0                 11                  Unique number linking OUT to DEMO
# 1                 12  AgeGroup_Lx.Code. Age of patient at time of on...
# 2                 13                                     Gender_Lx.Code
# 3                 21  Date when report was entered into the database...
# 4                 22                   ReportType_Lx.Code. Report type.
# 5                 23                                    Region_lx.Code.
# 6                 31  Date when the first version of the report was ...
#       Table  No of rows
# 0       ADR    66802344
# 1      DEMO    27213386
# 2      DRUG    71006811
# 3  FOLLOWUP     7759897
# 4       IND    35474400
# 5      LINK    99273742
# 6       OUT    22677257
# 7      SRCE    21105031
#   0%|          | 0/27213386 [00:00<?, ?it/s]
#   UMCReportId AgeGroup Gender DateDatabase Type Region FirstDateDatabase
# 0    34777001        5      2     20210205    1      2          20210205
# 1    34776971        9      -     20210205    1      2          20210205
# 2    34776965        9      1     20210205    1      2          20210205
# 3    34776982        9      -     20210205    1      2          20210205
# 4    34776980        9      -     20210205    1      2          20210205

# %%
df.to_csv(CSV_DATA_DIR / f"{table_name}.csv")
print(f"Saved {table_name}.csv!")
del df
# Out:
# Saved DEMO.csv!

# %%
table_name = "DRUG"

# Get Manifest
fpath = MANIFEST_DATA_DIR / f"{table_name}.csv"
manifest_adr = pd.read_csv(fpath, index_col=0)
columns_adr = manifest_adr["column_name"].values
display(manifest_adr)
manifest_adr = manifest_adr.to_dict(orient="records")

# Get Counts
fpath = MANIFEST_DATA_DIR / "count.csv"
count = pd.read_csv(fpath, index_col=0)
n_rows = count.loc[count["Table"] == table_name, "No of rows"].squeeze()
display(count)

# Parse text file
fpath = MAIN_TXT_DATA_DIR / f"{table_name}.txt"
results = [None for _ in range(n_rows)]
result = [None for _ in range(len(manifest_adr))]
with open(fpath) as file:
  for idx, line in tqdm(enumerate(file), total=n_rows):
      for icol, col in enumerate(manifest_adr):
        char_start = col["char_position_start"]
        char_end = col["char_position_end"]
        result[icol] =  line[char_start: char_end].rstrip()
      results[idx] = tuple(result)
df = pd.DataFrame(results, columns=columns_adr)
df.head()
# Out:
#          column_name          dtype  number_of_chars  char_position_start  \
# 0        UMCReportId  <class 'int'>               11                    0
# 1            Drug_Id  <class 'int'>               11                   11
# 2   MedicinalProd_Id  <class 'int'>               11                   22
# 3             DrecNo  <class 'str'>                6                   33
# 4               Seq1  <class 'str'>                2                   39
# 5               Seq2  <class 'str'>                3                   41
# 6              Route  <class 'str'>                2                   44
# 7              Basis  <class 'str'>                1                   46
# 8             Amount  <class 'str'>                5                   47
# 9            AmountU  <class 'str'>                2                   52
# 10         Frequency  <class 'str'>                2                   54
# 11        FrequencyU  <class 'str'>                3                   56
#
#     char_position_end                                              notes
# 0                  11                 Unique number linking DRUG to DEMO
# 1                  22         Unique number identifying each row in DRUG
# 2                  33  A sequential number generated for each Medicin...
# 3                  39                                 Drug record number
# 4                  41                                  Sequence number 1
# 5                  44                                  Sequence number 2
# 6                  46  RouteOfAdm_Lx.Code. Route of administration of...
# 7                  47   RepBasis_Lx.Code. Characterization of drug role.
# 8                  52                             Dosage regimen; Amount
# 9                  54                     SizeUnit_Lx.Code. Amount unit.
# 10                 56                    Number of units in the interval
# 11                 59     Frequency_Lx.Code. Definition of the interval.
#       Table  No of rows
# 0       ADR    66802344
# 1      DEMO    27213386
# 2      DRUG    71006811
# 3  FOLLOWUP     7759897
# 4       IND    35474400
# 5      LINK    99273742
# 6       OUT    22677257
# 7      SRCE    21105031
#   0%|          | 0/71006811 [00:00<?, ?it/s]
#   UMCReportId Drug_Id MedicinalProd_Id  DrecNo Seq1 Seq2 Route Basis Amount  \
# 0    34777001      10          1240849  003819   01  029    15     1      -
# 1    34777001      42          1240849  003819   01  029    15     1      -
# 2    34776971      19          4134085  056993   01  002    65     1      -
# 3    34776971      27          4134085  056993   01  002     -     1      -
# 4    34776965      18          4239665  088719   02  002    65     1      -
#
#   AmountU Frequency FrequencyU
# 0       -         -          -
# 1       -         -          -
# 2       -         -          -
# 3       -         -          -
# 4       -         -          -

# %%
df.to_csv(CSV_DATA_DIR / f"{table_name}.csv")
print(f"Saved {table_name}.csv!")
del df
# Out:
# Saved DRUG.csv!

# %%
table_name = "FOLLOWUP"

# Get Manifest
fpath = MANIFEST_DATA_DIR / f"{table_name}.csv"
manifest_adr = pd.read_csv(fpath, index_col=0)
columns_adr = manifest_adr["column_name"].values
display(manifest_adr)
manifest_adr = manifest_adr.to_dict(orient="records")

# Get Counts
fpath = MANIFEST_DATA_DIR / "count.csv"
count = pd.read_csv(fpath, index_col=0)
n_rows = count.loc[count["Table"] == table_name, "No of rows"].squeeze()
display(count)

# Parse text file
fpath = MAIN_TXT_DATA_DIR / f"{table_name}.txt"
results = [None for _ in range(n_rows)]
result = [None for _ in range(len(manifest_adr))]
with open(fpath) as file:
  for idx, line in tqdm(enumerate(file), total=n_rows):
    for icol, col in enumerate(manifest_adr):
      char_start = col["char_position_start"]
      char_end = col["char_position_end"]
      result[icol] =  line[char_start: char_end].rstrip()
    results[idx] = tuple(result)
df = pd.DataFrame(results, columns=columns_adr)
df.head()
# Out:
#            column_name          dtype  number_of_chars  char_position_start  \
# 0          UMCReportId  <class 'int'>               11                    0
# 1  ReplacedUMCReportId  <class 'int'>               11                   11
#
#    char_position_end                                              notes
# 0                 11  Unique number linking FOLLOWUP to DEMO. This n...
# 1                 22  Previous versions of the case, no longer avail...
#       Table  No of rows
# 0       ADR    66802344
# 1      DEMO    27213386
# 2      DRUG    71006811
# 3  FOLLOWUP     7759897
# 4       IND    35474400
# 5      LINK    99273742
# 6       OUT    22677257
# 7      SRCE    21105031
#   0%|          | 0/7759897 [00:00<?, ?it/s]
#   UMCReportId ReplacedUMCReportId
# 0    23711586            22149020
# 1    23711587            22149082
# 2    23711585            22149019
# 3    23711576            22149231
# 4    23711574            22149228

# %%
# results

# %%
table_name = "IND"

# Get Manifest
fpath = MANIFEST_DATA_DIR / f"{table_name}.csv"
manifest_adr = pd.read_csv(fpath, index_col=0)
columns_adr = manifest_adr["column_name"].values
display(manifest_adr)
manifest_adr = manifest_adr.to_dict(orient="records")

# Get Counts
fpath = MANIFEST_DATA_DIR / "count.csv"
count = pd.read_csv(fpath, index_col=0)
n_rows = count.loc[count["Table"] == table_name, "No of rows"].squeeze()
display(count)

# Parse text file
fpath = MAIN_TXT_DATA_DIR / f"{table_name}.txt"
results = [None for _ in range(n_rows)]
result = [None for _ in range(len(manifest_adr))]
with open(fpath, encoding="latin-1") as file:
# pd.read_csv(fpath, delim_whitespace="", skiprows=lambda x: x != 385_757, encoding='latin-1', nrows=1)
#   file.reead
  for idx, line in tqdm(enumerate(file), total=n_rows):
    # if idx > 385_757:
    # if idx > 385_000:
      # print(line)
    for icol, col in enumerate(manifest_adr):
      char_start = col["char_position_start"]
      char_end = col["char_position_end"]
      result[icol] =  line[char_start: char_end].rstrip()
    results[idx] = tuple(result)
df = pd.DataFrame(results, columns=columns_adr)
df.head()
# Out:
#   column_name          dtype  number_of_chars  char_position_start  \
# 0     Drug_Id  <class 'int'>               11                    0
# 1  Indication  <class 'str'>              255                   11
#
#    char_position_end                                              notes
# 0                 11                  Unique number linking IND to DRUG
# 1                266  Reason for drug use. Indication can be decoded...
#       Table  No of rows
# 0       ADR    66802344
# 1      DEMO    27213386
# 2      DRUG    71006811
# 3  FOLLOWUP     7759897
# 4       IND    35474400
# 5      LINK    99273742
# 6       OUT    22677257
# 7      SRCE    21105031
#   0%|          | 0/35474400 [00:00<?, ?it/s]
#   Drug_Id                    Indication
# 0      42                 Contraception
# 1      19  Cold type haemolytic anaemia
# 2      27                 Off label use
# 3      18       Spinal muscular atrophy
# 4       6              Hyperchlorhydria

# %%
# help(pd.read_csv)

# %%
# results

# %%
df.to_csv(CSV_DATA_DIR / f"{table_name}.csv")
print(f"Saved {table_name}.csv!")
# Out:
# Saved IND.csv!

# %%
# help(tqdm)

# %%
print("DONE)
# Out:
#   Input In [8]
#     print("DONE)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
# Verify that the last column is 8 + 1 characters (8 for MedDRA_id, 1 for Outcome)
# result["MedDRA_Id___Outcome"].str.len()

# %%
# Split entries of the last column into two
# result["MedDRA_Id"] = result["MedDRA_Id___Outcome"].str[:-1]
# result["Outcome"] = result["MedDRA_Id___Outcome"].str.slice(-1)
# result = result.drop(["MedDRA_Id___Outcome"], axis="columns")
result
# Out:
#                                  0
# 0  34777001   15         100125781
# 1  34776971   27         100537626
# 2  34776965   5          100192116
# 3  34776982   17         100383896
# 4  34776980   32         100369186
# 5  34776980   33         100050116
# 6  34776999   16         100708635
# 7  34776984   21         100119065
# 8  34776989   29         100626856
# 9  34776974   22         100807516

# %%
fpath = MAIN_TXT_DATA_DIR / "DEMO.txt"
result = pd.read_csv(fpath, nrows=10, header=None, delim_whitespace=" ")
demo_columns = ["UMCReportId", "AgeGroup", "Gender", "DateDatabase", "Type", "Region", "FirstDateDatabase"]
result
# Out:
#           0                     1
# 0  34777001  52202102051220210205
# 1  34776971  9-202102051220210205
# 2  34776965  91202102051220210205
# 3  34776982  9-202102051220210205
# 4  34776980  9-202102051220210205
# 5  34776999  72202102051220210205
# 6  34776984  81202102052220210205
# 7  34776989  62202102051220210205
# 8  34776974  92202102052220210205
# 9  34776991  92202102051220210205

# %%
result["UMCReportId"] = result[0]
result["AgeGroup"] = result[1].str[:1]
result["Gender"] = result[1].str[1:2]
result["DateDatabase"] = result[1].str[2:10]
result["Type"] = result[1].str[10:11]
result["Region"] = result[1].str[11:12]
result["FirstDateDatabase"] = result[1].str[12:]
result
result = result.drop([0, 1], axis="columns")
result
# Out:
#    UMCReportId AgeGroup Gender DateDatabase Type Region FirstDateDatabase
# 0     34777001        5      2     20210205    1      2          20210205
# 1     34776971        9      -     20210205    1      2          20210205
# 2     34776965        9      1     20210205    1      2          20210205
# 3     34776982        9      -     20210205    1      2          20210205
# 4     34776980        9      -     20210205    1      2          20210205
# 5     34776999        7      2     20210205    1      2          20210205
# 6     34776984        8      1     20210205    2      2          20210205
# 7     34776989        6      2     20210205    1      2          20210205
# 8     34776974        9      2     20210205    2      2          20210205
# 9     34776991        9      2     20210205    1      2          20210205

# %%
# result = pd.read_csv(fpath, nrows=10, header=None, delim_whitespace="")
# result = pd.read_csv(fpath, header=None, delim_whitespace="")
# drug_columns = ["UMCReportId", "Drug_Id", "MedicinalProd_Id", "DrecNo", "Seq1", "Seq2", "Route", "Basis", "Amount", "AmountU", "Frequency", "FrequencyU"]
# result

# %%
fpath = MAIN_TXT_DATA_DIR / "DRUG.txt"
result_df = pd.DataFrame()
n_rows = 71_006_811
# n_rows = 300
chunk_size = 5_000_000
results =  [None for _ in range(chunk_size)]
# results =  [None for _ in range(n_rows)]
columns_drug = (
                  "UMCReportId",
                  "Drug_Id",
                  "MedicinalProd_Id",
                  "DrecNo",
                  "Seq1",
                  "Seq2",
                  "Route",
                  "Basis",
                  "Amount",
                  "AmountU",
                  "Frequency",
                  "FrequencyU",
                )
with open(fpath) as file:
  # result = {}
  for idx, line in tqdm(enumerate(file)):
      # print(line.rstrip())
      # print(len(line.rstrip()))
      # print(len(line))
      UMCReportId      = line[0:11]
      Drug_Id          = line[11:22]
      MedicinalProd_Id = line[22:33]
      DrecNo           = line[33:39]
      Seq1             = line[39:41]
      Seq2             = line[41:44]
      Route            = line[44:46]
      Basis            = line[46:47]
      Amount           = line[47:52]
      AmountU          = line[52:54]
      Frequency        = line[54:56]
      FrequencyU       = line[56:59]
      # print(line)
      result = (
        val.rstrip() for val in 
                (
                  UMCReportId,
                  Drug_Id,
                  MedicinalProd_Id ,
                  DrecNo,
                  Seq1,
                  Seq2,
                  Route,
                  Basis,
                  Amount,
                  AmountU,
                  Frequency,
                  FrequencyU,
                )
      )
      # result = {k: v.rstrip() for k,v in result.items()}
      # result_df.iloc[idx] = result
      # results[idx] = result
      results[idx % chunk_size] = result
      # if idx >= n_rows - 1:
      if idx % chunk_size == 0:
        if idx == 0:
          continue
        df = pd.DataFrame(results, columns=columns_drug)
        chunk = int(idx // chunk_size)
        df.to_csv(CSV_DATA_DIR / f"DRUG_{chunk}.csv")
        results =  [None for _ in range(chunk_size)]
        del df
# result_df
# pd.DataFrame(results, columns=columns_drug)

results = [result for result in results if result is not None]
df = pd.DataFrame(results, columns=columns_drug)
df.to_csv(CSV_DATA_DIR / f"DRUG_{chunk + 1}.csv")
# Out:
# 0it [00:00, ?it/s]

# %%
result_df = pd.DataFrame(results, columns=columns_drug)
result_df

# %%
# result_df = pd.DataFrame()
# with open(fpath) as file:
#   result = {}
#   for line in file:
#       # print(line.rstrip())
#       # print(len(line.rstrip()))
#       # print(len(line))
#       # result["Drug_Id"]        = line[:11]
#       # result["Adr_Id"]         = line[11:22]
#       # result["Dechallenge1"]   = line[22]
#       # result["Dechallenge2"]   = line[23]
#       # result["Rechallenge1"]   = line[24]
#       # result["Rechallenge2"]   = line[25]
#       # result["TimeToOnsetMin"] = line[26:37]
#       # result["TimeToOnsetMax"] = line[37:48]
#
#
#       result["UMCReportId"]      = line[0:11]
#       result["Drug_Id"]          = line[11:22]
#       result["MedicinalProd_Id"] = line[22:33]
#       result["DrecNo"]           = line[33:39]
#       result["Seq1"]             = line[39:41]
#       result["Seq2"]             = line[41:44]
#       result["Route"]            = line[44:46]
#       result["Basis"]            = line[46:47]
#       result["Amount"]           = line[47:52]
#       result["AmountU"]          = line[52:54]
#       result["Frequency"]        = line[54:56]
#       result["FrequencyU"]       = line[56:59]
#       # print(line)
#       result = {k: v.rstrip() for k,v in result.items()}
#       result_df = result_df.append(result, ignore_index=True)
# result_df

# %%
result["UMCReportId"] = result[0].str[0:11]
result["Drug_Id"] = result[0].str[11:22]
result["MedicinalProd_Id"] = result[0].str[22:33]
result["DrecNo"] = result[0].str[33:39]
result["Seq1"] = result[0].str[39:41]
result["Seq2"] = result[0].str[41:44]
result["Route"] = result[0].str[44:46]
result["Basis"] = result[0].str[46:47]
result["Amount"] = result[0].str[47:52]
result["AmountU"] = result[0].str[52:54]
result["Frequency"] = result[0].str[54:56]
result["FrequencyU"] = result[0].str[56:59]
result = result.drop(0, axis="columns")
result

# %%
result.to_csv(CSV_DATA_DIR / "DRUG.csv")

# %%
# fpath = MAIN_TXT_DATA_DIR / "LINK.txt"
# # result = pd.read_csv(fpath, nrows=100, header=None, delim_whitespace="")
# result = pd.read_csv(fpath, header=None, delim_whitespace="")
# # result

# %%
# result["Drug_Id"] = result[0].str[:11]
# result["Adr_Id"] = result[0].str[11:22]
# result["Dechallenge1"] = result[0].str[22]
# result["Dechallenge2"] = result[0].str[23]
# result["Rechallenge1"] = result[0].str[24]
# result["Rechallenge2"] = result[0].str[25]
# result["TimeToOnsetMin"] = result[0].str[26:37]
# result["TimeToOnsetMax"] = result[0].str[37:48]
# result = result.drop(0, axis="columns")
# result
# result.to_csv(CSV_DATA_DIR / "LINK.csv")
# Out:
#               Drug_Id       Adr_Id Dechallenge1 Dechallenge2 Rechallenge1  \
# 0         10           15                     6            1            -
# 1         42           15                     6            1            -
# 2         19           27                     5            5            -
# 3         27           27                     5            5            -
# 4         18           5                      5            5            1
# ...               ...          ...          ...          ...          ...
# 99273737  71006805     66802340               5            4            4
# 99273738  71006811     66802341               5            4            4
# 99273739  71006811     66802342               5            4            4
# 99273740  71006811     66802343               5            4            4
# 99273741  71006811     66802344               5            4            4
#
#          Rechallenge2 TimeToOnsetMin TimeToOnsetMax
# 0                   -    -              -
# 1                   -    -              -
# 2                   -    -              -
# 3                   -    -              -
# 4                   3    -              -
# ...               ...            ...            ...
# 99273737            3    335.00069      396.99931
# 99273738            3    -27.99931      27.99931
# 99273739            3    -27.99931      27.99931
# 99273740            3    -27.99931      27.99931
# 99273741            3    -27.99931      27.99931
#
# [99273742 rows x 8 columns]

# %%
# table_names = [
#   "ADR",
#   "DEMO",
#   "DRUG",
#   "FOLLOWUP",
#   "IND",
#   "LINK",
#   "OUT",
#   "SRCE",
# ]

# %%
# i_table = 2
# table_name = table_names[i_table]
# print(table_name)
# fpath = MAIN_TXT_DATA_DIR / f"{table_name}.txt"
# result = pd.read_csv(fpath, nrows=100, header=None, delim_whitespace=True)
# # result = pd.read_csv(fpath, header=None, delim_whitespace=" ")
# # result.columns = ["UMCReportId", "Seriousness", "Serious"]
# result
# # result.to_csv(CSV_DATA_DIR / "OUT.csv")

# %%
  # fpath = MAIN_TXT_DATA_DIR / "SRCE.txt"
# result = pd.read_csv(fpath, header=None, delim_whitespace=" ")
# result.columns = ["UMCReportId", "Type"]
# result result.to_csv(CSV_DATA_DIR / "SRCE.csv")

# %%
del result
